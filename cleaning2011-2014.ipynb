# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium 
import openpyxl

# %%
# Define the sheet names in a list so that we can easily iterate through the excel sheets (tabs). 
# Each sheet is a year between 2002 and 2023

sheet_names = []
for n in range(2011, 2015, 1):
    sheet_names.append(str(n))

# %%
# Creating a dictionary of dataframes, one dataframe per excel sheet. 
# this will allow us to tailor our data cleaning to the individual sheet since the format of the sheet changes over the years.

DataFrame_dict = {}


for sheet in sheet_names:
    DataFrame_dict["sheet{0}".format(sheet)] = pd.read_excel('DOE_Electric_Disturbance_Events.xlsx', engine='openpyxl', header=1, sheet_name=sheet)

# %%
DataFrame_dict["sheet2012"]
# Out:
#                                       Date Event Began Time Event Began  \
# 0                                            January                NaN
# 1                                  2012-01-04 00:00:00         12:14:00
# 2                                  2012-01-05 00:00:00         10:35:00
# 3                                  2012-01-05 00:00:00         10:28:00
# 4                                  2012-01-09 00:00:00         14:30:00
# ..                                                 ...              ...
# 217                                2012-12-25 00:00:00         00:45:00
# 218                                2012-12-25 00:00:00         09:28:00
# 219                                2012-12-26 00:00:00         14:50:00
# 220                                2012-12-31 00:00:00         14:21:00
# 221  1 Source: Submissions of all Electric Emergenc...              NaN
#
#      Date of Restoration Time of Restoration  \
# 0                    NaN                None
# 1    2012-01-04 00:00:00            12:14:00
# 2    2012-01-05 00:00:00            12:25:00
# 3    2012-01-05 00:00:00            12:25:00
# 4    2012-01-09 00:00:00            15:30:00
# ..                   ...                 ...
# 217  2012-12-28 00:00:00            16:15:00
# 218  2012-12-26 00:00:00            16:28:00
# 219  2012-12-26 00:00:00            19:40:00
# 220  2012-12-31 00:00:00            16:30:00
# 221                  NaN                 NaN
#
#                                 Area Affected NERC Region  \
# 0                                         NaN         NaN
# 1                          Tacoma, Washington        WECC
# 2           CSWS/AEP West territory, Oklahoma         SPP
# 3                      Creek County, Oklahoma         SPP
# 4                      Watertown, Connecticut        NPCC
# ..                                        ...         ...
# 217  Arkansas; Louisiana; Mississippi; Texas          SPP
# 218                            Houston, Texas         TRE
# 219              Stantonsburg, North Carolina        SERC
# 220                            North Carolina        SERC
# 221                                       NaN         NaN
#
#                                   Event Type Demand Loss (MW)  \
# 0                                        NaN              NaN
# 1                  Suspected physical attack              NaN
# 2                                   Sabotage                0
# 3                  Suspected physical attack              NaN
# 4                                  Vandalism              NaN
# ..                                       ...              ...
# 217            Severe Weather - Winter Storm          Unknown
# 218  Severe Weather - Cold Front, High Winds              294
# 219            Severe Weather - Thunderstorm                3
# 220                Transmission Interruption               40
# 221                                      NaN              NaN
#
#     Number of Customers Affected  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 0                            NaN         NaN          NaN          NaN
# 1                            NaN         NaN          NaN          NaN
# 2                              0         NaN          NaN          NaN
# 3                            NaN         NaN          NaN          NaN
# 4                            NaN         NaN          NaN          NaN
# ..                           ...         ...          ...          ...
# 217                       242509         NaN          NaN          NaN
# 218                       262000         NaN          NaN          NaN
# 219                         1200         NaN          NaN          NaN
# 220                        12000         NaN          NaN          NaN
# 221                          NaN         NaN          NaN          NaN
#
# [222 rows x 12 columns]

# %%
from datetime import datetime

def drop_non_datetime_values(dataframe_name, column_name):
    for ind, row in dataframe_name.iterrows():
        if type(dataframe_name[column_name][ind]) == datetime:
            pass
        else:
            dataframe_name.drop(axis=0, index=ind, inplace=True)
    return dataframe_name

# %%
for sheet in list(range(2011,2015,1)):
    drop_non_datetime_values(DataFrame_dict["sheet{0}".format(sheet)], "Date Event Began")

# %%
#Let us make sure the first column contains the date only. initially some cells had date and time values which resulted in an error when I tried to merge columns later on

for sheet in list(range(2011,2014,1)):
    DataFrame_dict["sheet{0}".format(sheet)]['Date Event Began'] = pd.to_datetime(DataFrame_dict["sheet{0}".format(sheet)]['Date Event Began']).dt.date

# %%
DataFrame_dict["sheet2012"]
# Out:
#     Date Event Began Time Event Began  Date of Restoration  \
# 1         2012-01-04         12:14:00  2012-01-04 00:00:00
# 2         2012-01-05         10:35:00  2012-01-05 00:00:00
# 3         2012-01-05         10:28:00  2012-01-05 00:00:00
# 4         2012-01-09         14:30:00  2012-01-09 00:00:00
# 5         2012-01-09         13:36:00  2012-01-11 00:00:00
# ..               ...              ...                  ...
# 216       2012-12-17         06:55:00  2012-12-17 00:00:00
# 217       2012-12-25         00:45:00  2012-12-28 00:00:00
# 218       2012-12-25         09:28:00  2012-12-26 00:00:00
# 219       2012-12-26         14:50:00  2012-12-26 00:00:00
# 220       2012-12-31         14:21:00  2012-12-31 00:00:00
#
#     Time of Restoration                             Area Affected NERC Region  \
# 1              12:14:00                        Tacoma, Washington        WECC
# 2              12:25:00         CSWS/AEP West territory, Oklahoma         SPP
# 3              12:25:00                    Creek County, Oklahoma         SPP
# 4              15:30:00                    Watertown, Connecticut        NPCC
# 5              01:05:00                                 Louisiana        SERC
# ..                  ...                                       ...         ...
# 216            07:00:00                        Tacoma, Washington        WECC
# 217            16:15:00  Arkansas; Louisiana; Mississippi; Texas          SPP
# 218            16:28:00                            Houston, Texas         TRE
# 219            19:40:00              Stantonsburg, North Carolina        SERC
# 220            16:30:00                            North Carolina        SERC
#
#                                   Event Type Demand Loss (MW)  \
# 1                  Suspected physical attack              NaN
# 2                                   Sabotage                0
# 3                  Suspected physical attack              NaN
# 4                                  Vandalism              NaN
# 5                                  Load Shed              150
# ..                                       ...              ...
# 216                Suspected Physical Attack                0
# 217            Severe Weather - Winter Storm          Unknown
# 218  Severe Weather - Cold Front, High Winds              294
# 219            Severe Weather - Thunderstorm                3
# 220                Transmission Interruption               40
#
#     Number of Customers Affected  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 1                            NaN         NaN          NaN          NaN
# 2                              0         NaN          NaN          NaN
# 3                            NaN         NaN          NaN          NaN
# 4                            NaN         NaN          NaN          NaN
# 5                              1         NaN          NaN          NaN
# ..                           ...         ...          ...          ...
# 216                            0         NaN          NaN          NaN
# 217                       242509         NaN          NaN          NaN
# 218                       262000         NaN          NaN          NaN
# 219                         1200         NaN          NaN          NaN
# 220                        12000         NaN          NaN          NaN
#
# [196 rows x 12 columns]

# %%
for sheet in list(range(2011,2015,1)):
    DataFrame_dict["sheet{0}".format(sheet)]['Date Event Began'] = pd.to_datetime(DataFrame_dict["sheet{0}".format(sheet)]['Date Event Began'].astype(str) + ' ' + DataFrame_dict["sheet{0}".format(sheet)]["Time Event Began"].astype(str))

# %%
DataFrame_dict["sheet2012"]["Date of Restoration"][3]
DataFrame_dict["sheet2012"]
# Out:
#         Date Event Began Time Event Began  Date of Restoration  \
# 1    2012-01-04 12:14:00         12:14:00  2012-01-04 00:00:00
# 2    2012-01-05 10:35:00         10:35:00  2012-01-05 00:00:00
# 3    2012-01-05 10:28:00         10:28:00  2012-01-05 00:00:00
# 4    2012-01-09 14:30:00         14:30:00  2012-01-09 00:00:00
# 5    2012-01-09 13:36:00         13:36:00  2012-01-11 00:00:00
# ..                   ...              ...                  ...
# 216  2012-12-17 06:55:00         06:55:00  2012-12-17 00:00:00
# 217  2012-12-25 00:45:00         00:45:00  2012-12-28 00:00:00
# 218  2012-12-25 09:28:00         09:28:00  2012-12-26 00:00:00
# 219  2012-12-26 14:50:00         14:50:00  2012-12-26 00:00:00
# 220  2012-12-31 14:21:00         14:21:00  2012-12-31 00:00:00
#
#     Time of Restoration                             Area Affected NERC Region  \
# 1              12:14:00                        Tacoma, Washington        WECC
# 2              12:25:00         CSWS/AEP West territory, Oklahoma         SPP
# 3              12:25:00                    Creek County, Oklahoma         SPP
# 4              15:30:00                    Watertown, Connecticut        NPCC
# 5              01:05:00                                 Louisiana        SERC
# ..                  ...                                       ...         ...
# 216            07:00:00                        Tacoma, Washington        WECC
# 217            16:15:00  Arkansas; Louisiana; Mississippi; Texas          SPP
# 218            16:28:00                            Houston, Texas         TRE
# 219            19:40:00              Stantonsburg, North Carolina        SERC
# 220            16:30:00                            North Carolina        SERC
#
#                                   Event Type Demand Loss (MW)  \
# 1                  Suspected physical attack              NaN
# 2                                   Sabotage                0
# 3                  Suspected physical attack              NaN
# 4                                  Vandalism              NaN
# 5                                  Load Shed              150
# ..                                       ...              ...
# 216                Suspected Physical Attack                0
# 217            Severe Weather - Winter Storm          Unknown
# 218  Severe Weather - Cold Front, High Winds              294
# 219            Severe Weather - Thunderstorm                3
# 220                Transmission Interruption               40
#
#     Number of Customers Affected  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 1                            NaN         NaN          NaN          NaN
# 2                              0         NaN          NaN          NaN
# 3                            NaN         NaN          NaN          NaN
# 4                            NaN         NaN          NaN          NaN
# 5                              1         NaN          NaN          NaN
# ..                           ...         ...          ...          ...
# 216                            0         NaN          NaN          NaN
# 217                       242509         NaN          NaN          NaN
# 218                       262000         NaN          NaN          NaN
# 219                         1200         NaN          NaN          NaN
# 220                        12000         NaN          NaN          NaN
#
# [196 rows x 12 columns]

# %%
#Let us make sure the third column contains the date only. initially some cells had date and time values which resulted in an error when I tried to merge columns later on

for sheet in list(range(2011,2015,1)):
    for ind, row in DataFrame_dict["sheet{0}".format(sheet)].iterrows():
        if type(DataFrame_dict["sheet{0}".format(sheet)]['Date of Restoration'][ind]) != datetime:
            DataFrame_dict["sheet{0}".format(sheet)]['Date of Restoration'][ind] = datetime.now().date()
            #DataFrame_dict["sheet{0}".format(sheet)]['Time of Restoration'][ind] = datetime.now().time()
            
        if type(DataFrame_dict["sheet{0}".format(sheet)]['Time of Restoration'][ind]) == str:
            DataFrame_dict["sheet{0}".format(sheet)]['Time of Restoration'][ind] = "00:00:00"
    
    DataFrame_dict["sheet{0}".format(sheet)]['Date of Restoration'] = pd.to_datetime(DataFrame_dict["sheet{0}".format(sheet)]['Date of Restoration']).dt.date
# Out:
# c:\python36-32\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\python36-32\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
DataFrame_dict["sheet2012"]["Time of Restoration"][3]
# Out:
# datetime.time(12, 25)

# %%
for sheet in list(range(2011,2015,1)):
    DataFrame_dict["sheet{0}".format(sheet)]['Date of Restoration'] = pd.to_datetime(DataFrame_dict["sheet{0}".format(sheet)]['Date of Restoration'].astype(str) + ' ' + DataFrame_dict["sheet{0}".format(sheet)]["Time of Restoration"].astype(str))

# %%
DataFrame_dict["sheet2012"]
# Out:
#         Date Event Began Time Event Began  Date of Restoration  \
# 1    2012-01-04 12:14:00         12:14:00  2012-01-04 12:14:00
# 2    2012-01-05 10:35:00         10:35:00  2012-01-05 12:25:00
# 3    2012-01-05 10:28:00         10:28:00  2012-01-05 12:25:00
# 4    2012-01-09 14:30:00         14:30:00  2012-01-09 15:30:00
# 5    2012-01-09 13:36:00         13:36:00  2012-01-11 01:05:00
# ..                   ...              ...                  ...
# 216  2012-12-17 06:55:00         06:55:00  2012-12-17 07:00:00
# 217  2012-12-25 00:45:00         00:45:00  2012-12-28 16:15:00
# 218  2012-12-25 09:28:00         09:28:00  2012-12-26 16:28:00
# 219  2012-12-26 14:50:00         14:50:00  2012-12-26 19:40:00
# 220  2012-12-31 14:21:00         14:21:00  2012-12-31 16:30:00
#
#     Time of Restoration                             Area Affected NERC Region  \
# 1              12:14:00                        Tacoma, Washington        WECC
# 2              12:25:00         CSWS/AEP West territory, Oklahoma         SPP
# 3              12:25:00                    Creek County, Oklahoma         SPP
# 4              15:30:00                    Watertown, Connecticut        NPCC
# 5              01:05:00                                 Louisiana        SERC
# ..                  ...                                       ...         ...
# 216            07:00:00                        Tacoma, Washington        WECC
# 217            16:15:00  Arkansas; Louisiana; Mississippi; Texas          SPP
# 218            16:28:00                            Houston, Texas         TRE
# 219            19:40:00              Stantonsburg, North Carolina        SERC
# 220            16:30:00                            North Carolina        SERC
#
#                                   Event Type Demand Loss (MW)  \
# 1                  Suspected physical attack              NaN
# 2                                   Sabotage                0
# 3                  Suspected physical attack              NaN
# 4                                  Vandalism              NaN
# 5                                  Load Shed              150
# ..                                       ...              ...
# 216                Suspected Physical Attack                0
# 217            Severe Weather - Winter Storm          Unknown
# 218  Severe Weather - Cold Front, High Winds              294
# 219            Severe Weather - Thunderstorm                3
# 220                Transmission Interruption               40
#
#     Number of Customers Affected  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 1                            NaN         NaN          NaN          NaN
# 2                              0         NaN          NaN          NaN
# 3                            NaN         NaN          NaN          NaN
# 4                            NaN         NaN          NaN          NaN
# 5                              1         NaN          NaN          NaN
# ..                           ...         ...          ...          ...
# 216                            0         NaN          NaN          NaN
# 217                       242509         NaN          NaN          NaN
# 218                       262000         NaN          NaN          NaN
# 219                         1200         NaN          NaN          NaN
# 220                        12000         NaN          NaN          NaN
#
# [196 rows x 12 columns]

# %%
# Now that the "Date Event Began" column and "Date of Restoration" columns include datetime we can drop the "Time Event Began" and "Time of Restoration" columns 
# from the dataframes containing data for years 2011 - 2014

for sheet in list(range(2011,2015,1)):
    DataFrame_dict["sheet{0}".format(sheet)] = DataFrame_dict["sheet{0}".format(sheet)].drop(["Time Event Began", "Time of Restoration"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-a945cb4db131> in <module>()
#       3
#       4 for sheet in list(range(2011,2015,1)):
# ----> 5     DataFrame_dict["sheet{0}".format(sheet)] = DataFrame_dict["sheet{0}".format(sheet)].drop(["Time Event Began", "Time of Restoration"], axis=1)
#
# c:\python36-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# c:\python36-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# c:\python36-32\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3921                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3922             else:
# -> 3923                 new_axis = axis.drop(labels, errors=errors)
#    3924             result = self.reindex(**{axis_name: new_axis})
#    3925
#
# c:\python36-32\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5285         if mask.any():
#    5286             if errors != "ignore":
# -> 5287                 raise KeyError(f"{labels[mask]} not found in axis")
#    5288             indexer = indexer[~mask]
#    5289         return self.delete(indexer)
#
# KeyError: "['Time Event Began' 'Time of Restoration'] not found in axis"

# %%
DataFrame_dict["sheet2012"]
# Out:
#         Date Event Began  Date of Restoration  \
# 1    2012-01-04 12:14:00  2012-01-04 12:14:00
# 2    2012-01-05 10:35:00  2012-01-05 12:25:00
# 3    2012-01-05 10:28:00  2012-01-05 12:25:00
# 4    2012-01-09 14:30:00  2012-01-09 15:30:00
# 5    2012-01-09 13:36:00  2012-01-11 01:05:00
# ..                   ...                  ...
# 216  2012-12-17 06:55:00  2012-12-17 07:00:00
# 217  2012-12-25 00:45:00  2012-12-28 16:15:00
# 218  2012-12-25 09:28:00  2012-12-26 16:28:00
# 219  2012-12-26 14:50:00  2012-12-26 19:40:00
# 220  2012-12-31 14:21:00  2012-12-31 16:30:00
#
#                                 Area Affected NERC Region  \
# 1                          Tacoma, Washington        WECC
# 2           CSWS/AEP West territory, Oklahoma         SPP
# 3                      Creek County, Oklahoma         SPP
# 4                      Watertown, Connecticut        NPCC
# 5                                   Louisiana        SERC
# ..                                        ...         ...
# 216                        Tacoma, Washington        WECC
# 217  Arkansas; Louisiana; Mississippi; Texas          SPP
# 218                            Houston, Texas         TRE
# 219              Stantonsburg, North Carolina        SERC
# 220                            North Carolina        SERC
#
#                                   Event Type Demand Loss (MW)  \
# 1                  Suspected physical attack              NaN
# 2                                   Sabotage                0
# 3                  Suspected physical attack              NaN
# 4                                  Vandalism              NaN
# 5                                  Load Shed              150
# ..                                       ...              ...
# 216                Suspected Physical Attack                0
# 217            Severe Weather - Winter Storm          Unknown
# 218  Severe Weather - Cold Front, High Winds              294
# 219            Severe Weather - Thunderstorm                3
# 220                Transmission Interruption               40
#
#     Number of Customers Affected
# 1                            NaN
# 2                              0
# 3                            NaN
# 4                            NaN
# 5                              1
# ..                           ...
# 216                            0
# 217                       242509
# 218                       262000
# 219                         1200
# 220                        12000
#
# [196 rows x 7 columns]

# %%
post_cleaning_column_titles = ["datetime_event_began", "NERC_region", "area_affected", "event_type", "demand_loss_(MW)", "number_of_customers_affected", "datetime_of_restoration"]

# %%
# Now we need to reorder the columns so they are in the same order as the initial sheets we cleaned.

for sheet in list(range(2011,2015,1)):
    old_col = DataFrame_dict["sheet{0}".format(sheet)].columns.tolist()
    DataFrame_dict["sheet{0}".format(sheet)] = DataFrame_dict["sheet{0}".format(sheet)][[old_col[0], old_col[3], old_col[2], old_col[4], old_col[5], old_col[6], old_col[1]]]

# %%
for sheet in list(range(2011,2015,1)):
    old_col = DataFrame_dict["sheet{0}".format(sheet)].columns.tolist()
    for n in range(len(post_cleaning_column_titles)):
        DataFrame_dict["sheet{0}".format(sheet)] = DataFrame_dict["sheet{0}".format(sheet)].rename(columns={old_col[n]: post_cleaning_column_titles[n]})
        
    if len(old_col) > 7: #Drop all additional columns
        for x in range(7,len(old_col),1):
            DataFrame_dict["sheet{0}".format(sheet)] = DataFrame_dict["sheet{0}".format(sheet)].drop(old_col[x], axis=1)

# %%
DataFrame_dict["sheet2012"]
# Out:
#     datetime_event_began NERC_region  \
# 1    2012-01-04 12:14:00        WECC
# 2    2012-01-05 10:35:00         SPP
# 3    2012-01-05 10:28:00         SPP
# 4    2012-01-09 14:30:00        NPCC
# 5    2012-01-09 13:36:00        SERC
# ..                   ...         ...
# 216  2012-12-17 06:55:00        WECC
# 217  2012-12-25 00:45:00         SPP
# 218  2012-12-25 09:28:00         TRE
# 219  2012-12-26 14:50:00        SERC
# 220  2012-12-31 14:21:00        SERC
#
#                                 area_affected  \
# 1                          Tacoma, Washington
# 2           CSWS/AEP West territory, Oklahoma
# 3                      Creek County, Oklahoma
# 4                      Watertown, Connecticut
# 5                                   Louisiana
# ..                                        ...
# 216                        Tacoma, Washington
# 217  Arkansas; Louisiana; Mississippi; Texas
# 218                            Houston, Texas
# 219              Stantonsburg, North Carolina
# 220                            North Carolina
#
#                                   event_type demand_loss_(MW)  \
# 1                  Suspected physical attack              NaN
# 2                                   Sabotage                0
# 3                  Suspected physical attack              NaN
# 4                                  Vandalism              NaN
# 5                                  Load Shed              150
# ..                                       ...              ...
# 216                Suspected Physical Attack                0
# 217            Severe Weather - Winter Storm          Unknown
# 218  Severe Weather - Cold Front, High Winds              294
# 219            Severe Weather - Thunderstorm                3
# 220                Transmission Interruption               40
#
#     number_of_customers_affected datetime_of_restoration
# 1                            NaN     2012-01-04 12:14:00
# 2                              0     2012-01-05 12:25:00
# 3                            NaN     2012-01-05 12:25:00
# 4                            NaN     2012-01-09 15:30:00
# 5                              1     2012-01-11 01:05:00
# ..                           ...                     ...
# 216                            0     2012-12-17 07:00:00
# 217                       242509     2012-12-28 16:15:00
# 218                       262000     2012-12-26 16:28:00
# 219                         1200     2012-12-26 19:40:00
# 220                        12000     2012-12-31 16:30:00
#
# [196 rows x 7 columns]
