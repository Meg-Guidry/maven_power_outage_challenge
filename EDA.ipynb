# %% [markdown]
# # Maven Power Outage Challenge - Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium 
import openpyxl

# %%
disturbances = pd.read_csv("Disturbances2002_2023_cleaned.csv")

# %%
disturbances
# Out:
#       Unnamed: 0 datetime_event_began NERC_region  \
# 0              0  2002-01-30 06:00:00         SPP
# 1              1  2002-01-29 20:00:00         SPP
# 2              2  2002-01-30 16:00:00         SPP
# 3              3  2002-02-27 10:48:00        WSCC
# 4              4  2002-03-09 00:00:00        ECAR
# ...          ...                  ...         ...
# 1206        1206  2012-07-09 21:15:00        WECC
# 1207        1207  2012-07-17 03:27:00         SPP
# 1208        1208  2012-07-19 08:16:00         RFC
# 1209        1209  2012-07-19 10:20:00         RFC
# 1210        1210  2012-07-19 17:00:00         RFC
#
#                                           area_affected  \
# 0                                              Oklahoma
# 1                         Metropolitan Kansas City Area
# 2                                              Missouri
# 3                                            California
# 4                           Lower Peninsula of Michigan
# ...
